# %% [markdown]
# # PA ST 807: Convolutional Neural Network
# ## Homework 1: Artificial Neural Networks, Model Interpretation, and Regularization
#
# **GEC**<br/>
# **Instructor**: Pavlos Protopapas<br />
# **Maximum Score**: 100
#
# <hr style="height:2.4pt">

# %%
#RUN THIS CELL 
import requests
from IPython.core.display import HTML

# %%
import random
random.seed(112358)

import os
import sys

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

from sklearn.inspection import permutation_importance
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score, accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.utils import resample

# TensorFlow and tf.keras
import tensorflow as tf

# %matplotlib inline

# %% [markdown]
# ### INSTRUCTIONS
#
#
# - This homework is a jupyter notebook. Download and work on it on your local machine.
#
# - This homework should be submitted in pairs.
#
# - Ensure you and your partner together have submitted the homework only once. Multiple submissions of the same work will be penalised and will cost you 2 points.
#
# - Please restart the kernel and run the entire notebook again before you submit.
#
# - Running cells out of order is a common pitfall in Jupyter Notebooks. To make sure your code works restart the kernel and run the whole notebook again before you submit.
#
# - To submit the homework, either one of you upload the working notebook on edStem and click the submit button on the bottom right corner.
#
# - Submit the homework well before the given deadline. Submissions after the deadline will not be graded.
#
# - We have tried to include all the libraries you may need to do the assignment in the imports statement at the top of this notebook. We strongly suggest that you use those and not others as we may not be familiar with them.
#
# - Comment your code well. This would help the graders in case there is any issue with the notebook while running. It is important to remember that the graders will not troubleshoot your code.
#
# - Please use .head() when viewing data. Do not submit a notebook that is **excessively long**.
#
# - In questions that require code to answer, such as "calculate the $R^2$", do not just output the value from a cell. Write a `print()` function that includes a reference to the calculated value, **not hardcoded**. For example:
# ```
# print(f'The R^2 is {R:.4f}')
# ```
# - Your plots should include clear labels for the $x$ and $y$ axes as well as a descriptive title ("MSE plot" is not a descriptive title; "95 % confidence interval of coefficients of polynomial degree 5" is).
#
# - **Ensure you make appropraite plots for all the questions it is applicable to, regardless of it being explicitly asked for.**
#
# <hr style="height:2pt">

# %% [markdown]
# ### Names of the people who worked on this homework together
# #### /name here/

# %% [markdown]
# <a id="contents"></a>
#
# ## Notebook Contents
#
# - [**PART 1 [50 pts]: Model interpretation and predictive intervals in NN**](#part1)
#   - [Overview and Data Description](#part1intro)
#   - [Questions](#part1questions)
#   - [Solutions](#part1solutions)
#
#
# - [**PART 2 [50 pts]: Kannada MNIST Kaggle competition**](#part2)
#   - [Problem Statement](#part2intro)
#   - [The Kannada MNIST Dataset](#part2about)
#   - [Downloading the Data Files](#part2data)
#   - [Questions](#part2questions)
#   - [Solutions](#part2solutions)

# %% [markdown]
# ---

# %% [markdown]
# <div class="alert alert-block alert-danger" style="color:black;background-color:#E7F4FA">
# <h1> PART 1 [50 pts]: Model interpretation and predictive intervals in NN </h1>
#
# <br />
#
#
# <a id="part1intro"></a>
#
# <b> Overview and Data Description </b>
# <br /><br />
# [Return to contents](#contents)
# <br />
# In this problem, you will be building and interpreting models to predict whether a flight was delayed for its arrival based on features that could be measured as the flight takes off.
# We will also estimate the predictive intervals of the model using bootstrapping. We will utilize those predictive intervals to build a new kind of model: a model that refrains from making a prediction when it is not confident.
#
#
# The included variables are:
# <br /><br />
# **ARRIVAL_DELAY**: the difference between scheduled arrival and actual arrival, in minutes (positive is late, negative is early).
# <br /><br />
# **DISTANCE**: the distance between arrival and departure airports, in miles.
# <br /><br />
# **SCHEDULED_TIME**: the flight's scheduled travel time.
# <br /><br />
# **MONTH**: the month the flight took off, 1 = January, 2 = February, etc.
# <br /><br />
# **SCHED_DEP_HOUR**: the scheduled departure time (the hour of the day).
# <br /><br />
# **SCHED_ARR_HOUR**: the scheduled arrival time (the hour of the day).
# <br /><br />
# **FLIGHT_COUNT**: the number of flights flying out of that airport before noon on a typical day.
# <br /><br />
# **DAY_OF_WEEK**: the day of the week, 1 = Monday, 2 = Tuesday, etc.
# <br /><br />
# **ORIGIN_AIRPORT**: the airport the flight took off from.
# <br /><br />
# **DESTINATION_AIRPORT**: the airport the flight was scheduled to land at.
# <br /><br />
# For the airport codes, see: https://www.bts.gov/topics/airlines-and-airports/world-airport-codes
#
# To sucessfully complete this part, you will proceed by fitting a NN model, evaluating its accuracy, interpreting the predictors' importance, and finally evaluating the predictive intervals.
# <br /><br />
# **NOTE:** The observations were sampled so that roughly half of the observations were delayed and half of the observations were not delayed.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger" style="color:black;background-color:#E7F4FA">
#
# <h2>PART 1: Questions</h2>
# <br /><br />
#
# [Return to contents](#contents)
#
# <br /><br />
# **1.1.1 [5 points]**  Read in the dataset `flights.csv`. Create a variable `DELAY_OR_NOT` that denotes whether `ARRIVAL_DELAY` is greater than or equal to 15 minutes (the FAA and BTS define a flight as delayed only if it arrives 15 minutes late or more). This is going to be the response variable for the rest of this question.
# <br /><br />
# **1.1.2 [5 points]** Preprocess the data: one-hot-encode the non-numeric categorical variables, deal with missing values if there are any, scale your data, and split the data into training and test sets (use an 80/20 split with `random_state=111`). Print the resulting shapes of your $X$ and $y$ dataframes for both your train and your test sets.
# <br /><br />
# **1.2 [5 points]** Fit an artificial neural network model using all predictors (name this model `NN_model`).  Use a dense feed-forward network with two hidden layers with 15 nodes in each hidden layer. For this network, use appropriate activation functions for each layer, select an appropriate loss function and optimizer, specify a validation split of 0.2, train for an appropriate number of epochs based on the results of your training and validation accuracy plot, and feel free to use the default batch size while training. Plot the training accuracy and validation accuracy as a function of epochs from your `NN_model` training history. Evaluate the `NN_model` model on both train and test, and print out the resulting train and test accuracies.
# <br /><br />
# **1.3 [10 points]** To begin our interpretation of the resulting `NN_model`, we will first use a "proxy model" that we know how to interpret and train it on our `NN_model` training predictions.
#
# <br /><br />
# - **1.3.1** For this we need to modify our training set. First, generate a set of `NN_model` class predictions for the training set. These training predictions will be used to form a revised training dataset for our proxy model: (a) use all of the same $X$ values used by `NN_model` for our $X$ train and (b) replace the actual response values $y$ with the predicted $\hat{y}$ values generated by the fitted `NN_model`.
#
# <br /><br />
# - **1.3.2** Next, fit a logistic regression model using your revised training dataset from 1.3.1 (name this model `logreg`). Use ridge-like regularization. Print the `logreg` test accuracy to confirm that it is similar to what we saw for our `NN_model` test accuracy in 1.2. You may need to adjust `C` in order to achieve a similar accuracy.
#
# <br /><br />
# - **1.3.3** Now use sklearn's `permutation_importance` class (already included in this notebook's imports) to compute the feature importance using the `logreg` model.
# <br />
#   - Read the official documentation for `permutation_importance` [here](https://scikit-learn.org/stable/modules/permutation_importance.html#:~:text=The%20permutation%20feature%20importance%20is,model%20depends%20on%20the%20feature.) as well as [here](https://scikit-learn.org/stable/modules/generated/sklearn.inspection.permutation_importance.html#sklearn.inspection.permutation_importance) to learn how it works.
# <br />
#   - You can use the default number of `n_repeats` and your estimator's default `scorer`. To speed up the time it takes to run your permutations, you can try setting `n_jobs=-1` to take full advantage of all of your available processor cores.
# <br />
#   - Measure the **relative** variable importance (i.e. as a proportion of the variable importance of the most important variable identified by `permutation_importance`) and generate a barplot illustrating the relative variable importances for the top-10 most important predictors identified using `permutation_importance`.
# <br /><br />
#
# **1.4 [10 points]** Another way to interpret the  `NN_model` is by examining the response as a function of any of the predictors. Particularly, we will select from features often found most significant from the analysis above. **For all 1.4 plots below**, for ease of interpretation, **please be certain to** display all predictors on their original scales.
# <br /><br />
#
#    - **1.4.1** Set all predictors to their means/modes except for `SCHED_DEP_HOUR`. Predict the probability of delay and plot the predicted probabilities of delay vs. `SCHED_DEP_HOUR` on the data from the **training set**. Interpret what you see in 2-4 sentences.
# <br /><br />
#
#    - **1.4.2** Set all predictors to their means/modes except for `SCHED_DEP_HOUR` and `FLIGHT_COUNT`. Predict the probability of delay and plot the predicted probabilities of delay vs. `SCHED_DEP_HOUR` and `FLIGHT_COUNT` from the training set (see the question 1.4 "HINT" below).
#
# <br /><br />
#    - **1.4.3**   Set all predictors to their means/modes except for except for `SCHED_DEP_HOUR` and `SCHED_ARR_HOUR`. Predict the probability of delay and plot the predicted probabilities of delay vs. `SCHED_DEP_HOUR` and `SCHED_ARR_HOUR` from the training set.
#
# <br /><br />
#    - **1.4.4** Set all predictors to their means/modes except for except for `SCHED_DEP_HOUR` and `DISTANCE`. Predict the probability of delay and plot the predicted probabilities of delay vs. `SCHED_DEP_HOUR` and `DISTANCE` from the training set.
# <br /><br />
#
#   - **1.4.5** In 5-10 sentences, interpret what you have seen in 1.4.2, 1.4.3, and 1.4.4.
# <br /><br />
# **HINT:** For 1.4.2, 1.4.3, and 1.4.4, when you include `SCHED_DEP_HOUR` on one axis and your second predictor on the other axis, you can color your datapoints based on their corresponding predicted probabilities by using  the `c` and `cmap` arguments in `plt.scatter`. You can also add a labeled colorbar to your plot to make clear what those colors mean. Please refer to the matplotlib documentation for examples.
# <br /><br />
#
# **1.5 [5 points]**
#
# <br /><br />
# In this part, we will attempt to do model inference. Neural Networks have too many parameters, and therefore inference on all the parameters is intractable and meaningless.
# <br /><br />
# Using the same network architecture as `NN_model` (layers, nodes, activations, etc.) and your scaled data from that model, create multiple training sets using bootstrapping and fit a separate neural network model to each bootstrapped set of data (a minimum of at least 50 bootstraps should be used). Predict the output on the test data for each model. Randomly select 8 test observations and on 8 subplots, plot the distribution of predicted probabilities (i.e. $n$ bootstrapped probabilites) with the 95% CI bounds clearly marked and reported in each subplot and the actual class of each observation included in each subplot's title for easy reference.
#     <br /><br />
# Interpret what you see in 3-5 sentences.
# <br /><br />
#
# **NOTE:** The code for this problem can take an extremely long time to execute. Please feel free to use the provided `progressbar` function below to visually track the progress of your bootstraps.
#
# <br /><br />
#
# **1.6 [10 points]**
#
# <br /><br />
# Using the probability distribution of the predictions obtained from the bootstrapped samples above, we can evaluate how "significant" our bagged (i.e. bootstrap-aggregated) prediction will be for each test observation.
# <br /><br />
# To accomplish this, you will first calculate the ratio of bootstrapped probabilities that cross the threshold value of $\hat{p}=0.5$. Let's call this ratio the **Posterior Prediction Ratio (PPR)**. When a bagged prediction's $PPR=0$, all predictions are compatible (i.e. all bootstrapped probabilities for that test observation are on the same side of $\hat{p}=0.5$). Likewise, when the $PPR=0.5$, half of the bootstrapped predictions for that test observation are $\hat{y}=0$, and the other half are $\hat{y}=1$. After calculating your $PPR$ values for all test observations, you should have $n=2000$ $PPR$ values (i.e. one for each test observation).
# <br /><br />
# Next, to get more accurate predictions, we can create an **abstain** model that will abstain from making a prediction for a particular observation if some defined threshold for significance (i.e. maximum $PPR$ value) is not met. (If you'd like to learn more about abstain models, you can read more [here](https://openreview.net/forum?id=rJxF73R9tX).)
# <br /><br />
# Let's explore how your resulting test accuracies might change by using your bootstrapped prediction results from question 1.5 for an **abstain bagging model** (i.e. a bootstrap aggregated model where some test observations are simply not predicted based on a given $PPR$ threshold). You can make your abstain model *stricter* by using smaller $PPR$ threshold values.
# <br /><br />
# - Print the test accuracy for your **bagging model** predictions from question 1.5 using predictions for all 2,000 of our test observations.
# <br /><br />
# - Plot the test accuracies for an **abstain bagging model** using your predictions from question 1.5 as a function of increasing $PPR$.
# <br /><br />
# - Also, plot the proportion of test observations not abstained (i.e. the proportion of those predicted) for your **abstain bagging model** as a function of increasing $PPR$.
# <br /><br />
# - Interpret what you see in 3-5 sentences.
# <br /><br />
#
# **NOTE**: You should observe that as $PPR$ decreases (more confident predictions), you must also compromise on the number of points that your abstain model predicts confidently.
#
# </div>

# %% [markdown]
# <a id="part1solutions"></a>
#
# ## PART 1: Solutions
#
# [Return to contents](#contents)

# %% [markdown]
# <div class='exercise-r'>
#
# **1.1**
#
# </div>

# %%
# Read in the dataset flights.csv. Create a variable DELAY_OR_NOT that denotes whether ARRIVAL_DELAY is greater than or equal to 15 minutes 
# (the FAA and BTS define a flight as delayed only if it arrives 15 minutes late or more). This is going to be the response variable for the 
# rest of this question.
dataset = pd.read_csv('flights.csv')
DELAY_OR_NOT = dataset['ARRIVAL_DELAY']
DELAY_OR_NOT = [1 if i >=15 else 0 for i in DELAY_OR_NOT]

# %% [markdown]
# <div class='exercise-r'>
#
# **1.1.2**
#
# </div>

# %%
# Preprocess the data: one-hot-encode the non-numeric categorical variables, deal with missing values if there are any, 
# scale your data, and split the data into training and test sets (use an 80/20 split with random_state=111). 
# Print the resulting shapes of your  𝑋  and  𝑦  dataframes for both your train and your test sets.

# Change the Origin Airport and Destination Airport into One-hot code, the unmatched number will be considered as one type to make sure the integrity of data
ORIGIN_AIRPORT=dataset['ORIGIN_AIRPORT']
ORIGIN_AIRPORT= [ 'Unknown' if x.isdigit() else x for x in ORIGIN_AIRPORT ]
ORIGIN_AIRPORT = pd.get_dummies(ORIGIN_AIRPORT).values
DESTINATION_AIRPORT=dataset['DESTINATION_AIRPORT']
DESTINATION_AIRPORT= [ 'Unknown' if x.isdigit() else x for x in DESTINATION_AIRPORT ]
DESTINATION_AIRPORT = pd.get_dummies(DESTINATION_AIRPORT).values

# Change Date of Week and Month into One-hot code as well
DAY_OF_WEEK=dataset['DAY_OF_WEEK']
DAY_OF_WEEK = pd.get_dummies(DAY_OF_WEEK).values
MONTH = dataset['MONTH']
MONTH=pd.get_dummies(MONTH).values

# Using StandardScaler to do normalization with column DISTANCE, FLIGHT_COUNT, and SCHEDULED_TIME
scalar=StandardScaler()
DISTANCE=dataset['DISTANCE'].values.reshape(-1,1)
SCHEDULED_TIME=dataset['SCHEDULED_TIME'].values.reshape(-1,1)
FLIGHT_COUNT=dataset['FLIGHT_COUNT'].values.reshape(-1,1)
scalar.fit(DISTANCE)
DISTANCE=scalar.transform(DISTANCE)
scalar.fit(SCHEDULED_TIME)
SCHEDULED_TIME=scalar.transform(SCHEDULED_TIME)
scalar.fit(FLIGHT_COUNT)
FLIGHT_COUNT=scalar.transform(FLIGHT_COUNT)

# Also extract SCHED_DEP_HOUR and SCHED_ARR_HOUR, and convert them into One-hot patterns
SCHED_DEP_HOUR= dataset['SCHED_DEP_HOUR']
SCHED_ARR_HOUR =dataset['SCHED_ARR_HOUR']
SCHED_DEP_HOUR = pd.get_dummies(SCHED_DEP_HOUR).values
SCHED_ARR_HOUR = pd.get_dummies(SCHED_ARR_HOUR).values

# Assemble all predictors together as X, and DELAY_OR_NOT values as Y. Splitting train and test daatsets according to the requirement.
X=np.hstack([DISTANCE,SCHEDULED_TIME,MONTH,SCHED_DEP_HOUR,SCHED_ARR_HOUR,DAY_OF_WEEK,ORIGIN_AIRPORT,DESTINATION_AIRPORT])
y=np.array(DELAY_OR_NOT)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=111)
print(X_train.shape,X_test.shape,y_train.shape,y_test.shape)
# Out:
# (8000, 619) (2000, 619) (8000,) (2000,)

# %% [markdown]
# <div class='exercise-r'>
#
# **1.2**
#
# </div>

# %%
#Construct the model following the instruction, also use adagrad as Optimizer, since so much sparce data here
model = tf.keras.Sequential(name='NN_model')
model.add(tf.keras.layers.Dense(units=15,activation='elu'))
model.add(tf.keras.layers.Dense(units=15,activation='elu'))
model.add(tf.keras.layers.Dense(units=1,activation='sigmoid'))
model.compile(optimizer='adagrad',loss=tf.keras.losses.binary_crossentropy,metrics=['accuracy'])
model.build(input_shape=((64,619)))

# %%
# Shuffle the data and aslo add EarlyStop callback with patience = 10
EarlyStop=tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=10)
history = model.fit(X_train,y_train,verbose=1,batch_size=64,validation_split=0.2,epochs=500,shuffle = True,callbacks=[EarlyStop])
# Out:
# Epoch 1/500
# 100/100 [==============================] - 1s 5ms/step - loss: 0.7009 - accuracy: 0.4991 - val_loss: 0.6944 - val_accuracy: 0.5088
# Epoch 2/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.6941 - accuracy: 0.5191 - val_loss: 0.6881 - val_accuracy: 0.5269
# Epoch 3/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.6886 - accuracy: 0.5370 - val_loss: 0.6828 - val_accuracy: 0.5531
# Epoch 4/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.6837 - accuracy: 0.5559 - val_loss: 0.6781 - val_accuracy: 0.5750
# Epoch 5/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.6793 - accuracy: 0.5711 - val_loss: 0.6738 - val_accuracy: 0.5913
# Epoch 6/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.6752 - accuracy: 0.5841 - val_loss: 0.6699 - val_accuracy: 0.6012
# Epoch 7/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.6714 - accuracy: 0.5964 - val_loss: 0.6661 - val_accuracy: 0.6169
# Epoch 8/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.6677 - accuracy: 0.6092 - val_loss: 0.6625 - val_accuracy: 0.6338
# Epoch 9/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.6642 - accuracy: 0.6178 - val_loss: 0.6591 - val_accuracy: 0.6381
# Epoch 10/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6609 - accuracy: 0.6283 - val_loss: 0.6557 - val_accuracy: 0.6469
# Epoch 11/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.6576 - accuracy: 0.6366 - val_loss: 0.6525 - val_accuracy: 0.6538
# Epoch 12/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.6543 - accuracy: 0.6420 - val_loss: 0.6493 - val_accuracy: 0.6656
# Epoch 13/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.6512 - accuracy: 0.6506 - val_loss: 0.6462 - val_accuracy: 0.6675
# Epoch 14/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6481 - accuracy: 0.6577 - val_loss: 0.6431 - val_accuracy: 0.6719
# Epoch 15/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.6450 - accuracy: 0.6666 - val_loss: 0.6401 - val_accuracy: 0.6775
# Epoch 16/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6420 - accuracy: 0.6698 - val_loss: 0.6371 - val_accuracy: 0.6888
# Epoch 17/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.6390 - accuracy: 0.6752 - val_loss: 0.6342 - val_accuracy: 0.6950
# Epoch 18/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.6361 - accuracy: 0.6795 - val_loss: 0.6313 - val_accuracy: 0.7000
# Epoch 19/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.6332 - accuracy: 0.6848 - val_loss: 0.6285 - val_accuracy: 0.7044
# Epoch 20/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6304 - accuracy: 0.6892 - val_loss: 0.6257 - val_accuracy: 0.7075
# Epoch 21/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.6275 - accuracy: 0.6941 - val_loss: 0.6229 - val_accuracy: 0.7094
# Epoch 22/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.6247 - accuracy: 0.6995 - val_loss: 0.6202 - val_accuracy: 0.7119
# Epoch 23/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.6220 - accuracy: 0.7022 - val_loss: 0.6176 - val_accuracy: 0.7181
# Epoch 24/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.6193 - accuracy: 0.7059 - val_loss: 0.6149 - val_accuracy: 0.7156
# Epoch 25/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.6167 - accuracy: 0.7081 - val_loss: 0.6124 - val_accuracy: 0.7163
# Epoch 26/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6140 - accuracy: 0.7113 - val_loss: 0.6099 - val_accuracy: 0.7163
# Epoch 27/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.6115 - accuracy: 0.7130 - val_loss: 0.6074 - val_accuracy: 0.7163
# Epoch 28/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.6090 - accuracy: 0.7152 - val_loss: 0.6050 - val_accuracy: 0.7169
# Epoch 29/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.6065 - accuracy: 0.7169 - val_loss: 0.6026 - val_accuracy: 0.7206
# Epoch 30/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.6040 - accuracy: 0.7181 - val_loss: 0.6003 - val_accuracy: 0.7206
# Epoch 31/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.6017 - accuracy: 0.7212 - val_loss: 0.5980 - val_accuracy: 0.7231
# Epoch 32/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5993 - accuracy: 0.7203 - val_loss: 0.5958 - val_accuracy: 0.7237
# Epoch 33/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5971 - accuracy: 0.7230 - val_loss: 0.5936 - val_accuracy: 0.7237
# Epoch 34/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5948 - accuracy: 0.7241 - val_loss: 0.5915 - val_accuracy: 0.7250
# Epoch 35/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5927 - accuracy: 0.7255 - val_loss: 0.5895 - val_accuracy: 0.7256
# Epoch 36/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5906 - accuracy: 0.7258 - val_loss: 0.5875 - val_accuracy: 0.7269
# Epoch 37/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5885 - accuracy: 0.7262 - val_loss: 0.5856 - val_accuracy: 0.7269
# Epoch 38/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5865 - accuracy: 0.7262 - val_loss: 0.5837 - val_accuracy: 0.7300
# Epoch 39/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5845 - accuracy: 0.7270 - val_loss: 0.5819 - val_accuracy: 0.7319
# Epoch 40/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5826 - accuracy: 0.7273 - val_loss: 0.5801 - val_accuracy: 0.7331
# Epoch 41/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5808 - accuracy: 0.7284 - val_loss: 0.5784 - val_accuracy: 0.7344
# Epoch 42/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5790 - accuracy: 0.7295 - val_loss: 0.5767 - val_accuracy: 0.7362
# Epoch 43/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5772 - accuracy: 0.7300 - val_loss: 0.5751 - val_accuracy: 0.7362
# Epoch 44/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5755 - accuracy: 0.7309 - val_loss: 0.5736 - val_accuracy: 0.7375
# Epoch 45/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5739 - accuracy: 0.7316 - val_loss: 0.5721 - val_accuracy: 0.7356
# Epoch 46/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5723 - accuracy: 0.7323 - val_loss: 0.5707 - val_accuracy: 0.7350
# Epoch 47/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5707 - accuracy: 0.7331 - val_loss: 0.5693 - val_accuracy: 0.7356
# Epoch 48/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5692 - accuracy: 0.7341 - val_loss: 0.5679 - val_accuracy: 0.7350
# Epoch 49/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5677 - accuracy: 0.7341 - val_loss: 0.5666 - val_accuracy: 0.7362
# Epoch 50/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5663 - accuracy: 0.7341 - val_loss: 0.5653 - val_accuracy: 0.7356
# Epoch 51/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5650 - accuracy: 0.7348 - val_loss: 0.5641 - val_accuracy: 0.7362
# Epoch 52/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5636 - accuracy: 0.7358 - val_loss: 0.5630 - val_accuracy: 0.7387
# Epoch 53/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5623 - accuracy: 0.7353 - val_loss: 0.5618 - val_accuracy: 0.7387
# Epoch 54/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5611 - accuracy: 0.7359 - val_loss: 0.5608 - val_accuracy: 0.7387
# Epoch 55/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5599 - accuracy: 0.7359 - val_loss: 0.5597 - val_accuracy: 0.7381
# Epoch 56/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5587 - accuracy: 0.7361 - val_loss: 0.5587 - val_accuracy: 0.7369
# Epoch 57/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5576 - accuracy: 0.7358 - val_loss: 0.5577 - val_accuracy: 0.7362
# Epoch 58/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5565 - accuracy: 0.7372 - val_loss: 0.5568 - val_accuracy: 0.7369
# Epoch 59/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5554 - accuracy: 0.7369 - val_loss: 0.5559 - val_accuracy: 0.7362
# Epoch 60/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5544 - accuracy: 0.7372 - val_loss: 0.5550 - val_accuracy: 0.7375
# Epoch 61/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5534 - accuracy: 0.7378 - val_loss: 0.5542 - val_accuracy: 0.7381
# Epoch 62/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5525 - accuracy: 0.7383 - val_loss: 0.5534 - val_accuracy: 0.7394
# Epoch 63/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5515 - accuracy: 0.7389 - val_loss: 0.5526 - val_accuracy: 0.7381
# Epoch 64/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5506 - accuracy: 0.7394 - val_loss: 0.5519 - val_accuracy: 0.7387
# Epoch 65/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5497 - accuracy: 0.7403 - val_loss: 0.5512 - val_accuracy: 0.7387
# Epoch 66/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5489 - accuracy: 0.7398 - val_loss: 0.5505 - val_accuracy: 0.7387
# Epoch 67/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5481 - accuracy: 0.7402 - val_loss: 0.5498 - val_accuracy: 0.7381
# Epoch 68/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5473 - accuracy: 0.7405 - val_loss: 0.5492 - val_accuracy: 0.7381
# Epoch 69/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5465 - accuracy: 0.7408 - val_loss: 0.5486 - val_accuracy: 0.7381
# Epoch 70/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5458 - accuracy: 0.7411 - val_loss: 0.5480 - val_accuracy: 0.7369
# Epoch 71/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5450 - accuracy: 0.7412 - val_loss: 0.5474 - val_accuracy: 0.7356
# Epoch 72/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5443 - accuracy: 0.7419 - val_loss: 0.5469 - val_accuracy: 0.7362
# Epoch 73/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5437 - accuracy: 0.7428 - val_loss: 0.5464 - val_accuracy: 0.7362
# Epoch 74/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5430 - accuracy: 0.7431 - val_loss: 0.5459 - val_accuracy: 0.7362
# Epoch 75/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5424 - accuracy: 0.7427 - val_loss: 0.5454 - val_accuracy: 0.7362
# Epoch 76/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5417 - accuracy: 0.7437 - val_loss: 0.5449 - val_accuracy: 0.7369
# Epoch 77/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5411 - accuracy: 0.7439 - val_loss: 0.5445 - val_accuracy: 0.7381
# Epoch 78/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5405 - accuracy: 0.7428 - val_loss: 0.5440 - val_accuracy: 0.7387
# Epoch 79/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5400 - accuracy: 0.7439 - val_loss: 0.5436 - val_accuracy: 0.7387
# Epoch 80/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5394 - accuracy: 0.7448 - val_loss: 0.5432 - val_accuracy: 0.7394
# Epoch 81/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5389 - accuracy: 0.7445 - val_loss: 0.5428 - val_accuracy: 0.7387
# Epoch 82/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5384 - accuracy: 0.7447 - val_loss: 0.5425 - val_accuracy: 0.7394
# Epoch 83/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5378 - accuracy: 0.7448 - val_loss: 0.5421 - val_accuracy: 0.7394
# Epoch 84/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5373 - accuracy: 0.7456 - val_loss: 0.5418 - val_accuracy: 0.7394
# Epoch 85/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5369 - accuracy: 0.7459 - val_loss: 0.5414 - val_accuracy: 0.7387
# Epoch 86/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5364 - accuracy: 0.7455 - val_loss: 0.5411 - val_accuracy: 0.7387
# Epoch 87/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5359 - accuracy: 0.7453 - val_loss: 0.5408 - val_accuracy: 0.7387
# Epoch 88/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5355 - accuracy: 0.7456 - val_loss: 0.5405 - val_accuracy: 0.7387
# Epoch 89/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5351 - accuracy: 0.7456 - val_loss: 0.5402 - val_accuracy: 0.7387
# Epoch 90/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5346 - accuracy: 0.7453 - val_loss: 0.5399 - val_accuracy: 0.7375
# Epoch 91/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5342 - accuracy: 0.7453 - val_loss: 0.5396 - val_accuracy: 0.7369
# Epoch 92/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5338 - accuracy: 0.7450 - val_loss: 0.5394 - val_accuracy: 0.7369
# Epoch 93/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5334 - accuracy: 0.7448 - val_loss: 0.5391 - val_accuracy: 0.7375
# Epoch 94/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5330 - accuracy: 0.7444 - val_loss: 0.5389 - val_accuracy: 0.7387
# Epoch 95/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5327 - accuracy: 0.7447 - val_loss: 0.5386 - val_accuracy: 0.7387
# Epoch 96/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5323 - accuracy: 0.7439 - val_loss: 0.5384 - val_accuracy: 0.7387
# Epoch 97/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5319 - accuracy: 0.7447 - val_loss: 0.5382 - val_accuracy: 0.7387
# Epoch 98/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5316 - accuracy: 0.7445 - val_loss: 0.5380 - val_accuracy: 0.7394
# Epoch 99/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5312 - accuracy: 0.7448 - val_loss: 0.5378 - val_accuracy: 0.7400
# Epoch 100/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5309 - accuracy: 0.7447 - val_loss: 0.5376 - val_accuracy: 0.7400
# Epoch 101/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5306 - accuracy: 0.7450 - val_loss: 0.5374 - val_accuracy: 0.7400
# Epoch 102/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5303 - accuracy: 0.7447 - val_loss: 0.5372 - val_accuracy: 0.7394
# Epoch 103/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5299 - accuracy: 0.7450 - val_loss: 0.5370 - val_accuracy: 0.7394
# Epoch 104/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5296 - accuracy: 0.7450 - val_loss: 0.5368 - val_accuracy: 0.7406
# Epoch 105/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5293 - accuracy: 0.7450 - val_loss: 0.5367 - val_accuracy: 0.7406
# Epoch 106/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5290 - accuracy: 0.7455 - val_loss: 0.5365 - val_accuracy: 0.7412
# Epoch 107/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5288 - accuracy: 0.7462 - val_loss: 0.5363 - val_accuracy: 0.7412
# Epoch 108/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5285 - accuracy: 0.7467 - val_loss: 0.5362 - val_accuracy: 0.7419
# Epoch 109/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5282 - accuracy: 0.7473 - val_loss: 0.5360 - val_accuracy: 0.7412
# Epoch 110/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5279 - accuracy: 0.7478 - val_loss: 0.5359 - val_accuracy: 0.7419
# Epoch 111/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5277 - accuracy: 0.7477 - val_loss: 0.5357 - val_accuracy: 0.7419
# Epoch 112/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5274 - accuracy: 0.7481 - val_loss: 0.5356 - val_accuracy: 0.7419
# Epoch 113/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5271 - accuracy: 0.7473 - val_loss: 0.5355 - val_accuracy: 0.7412
# Epoch 114/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5269 - accuracy: 0.7477 - val_loss: 0.5353 - val_accuracy: 0.7419
# Epoch 115/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5266 - accuracy: 0.7478 - val_loss: 0.5352 - val_accuracy: 0.7419
# Epoch 116/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5264 - accuracy: 0.7478 - val_loss: 0.5351 - val_accuracy: 0.7425
# Epoch 117/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5262 - accuracy: 0.7481 - val_loss: 0.5350 - val_accuracy: 0.7431
# Epoch 118/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5259 - accuracy: 0.7478 - val_loss: 0.5349 - val_accuracy: 0.7431
# Epoch 119/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5257 - accuracy: 0.7477 - val_loss: 0.5347 - val_accuracy: 0.7431
# Epoch 120/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5255 - accuracy: 0.7483 - val_loss: 0.5346 - val_accuracy: 0.7437
# Epoch 121/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5252 - accuracy: 0.7486 - val_loss: 0.5345 - val_accuracy: 0.7425
# Epoch 122/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5250 - accuracy: 0.7487 - val_loss: 0.5344 - val_accuracy: 0.7425
# Epoch 123/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5248 - accuracy: 0.7492 - val_loss: 0.5343 - val_accuracy: 0.7425
# Epoch 124/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5246 - accuracy: 0.7489 - val_loss: 0.5342 - val_accuracy: 0.7425
# Epoch 125/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5244 - accuracy: 0.7492 - val_loss: 0.5341 - val_accuracy: 0.7431
# Epoch 126/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5242 - accuracy: 0.7492 - val_loss: 0.5340 - val_accuracy: 0.7425
# Epoch 127/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5240 - accuracy: 0.7492 - val_loss: 0.5339 - val_accuracy: 0.7425
# Epoch 128/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5238 - accuracy: 0.7495 - val_loss: 0.5339 - val_accuracy: 0.7425
# Epoch 129/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5236 - accuracy: 0.7497 - val_loss: 0.5338 - val_accuracy: 0.7431
# Epoch 130/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5234 - accuracy: 0.7502 - val_loss: 0.5337 - val_accuracy: 0.7431
# Epoch 131/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5232 - accuracy: 0.7503 - val_loss: 0.5336 - val_accuracy: 0.7425
# Epoch 132/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5230 - accuracy: 0.7505 - val_loss: 0.5335 - val_accuracy: 0.7425
# Epoch 133/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5228 - accuracy: 0.7503 - val_loss: 0.5334 - val_accuracy: 0.7419
# Epoch 134/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5226 - accuracy: 0.7505 - val_loss: 0.5334 - val_accuracy: 0.7412
# Epoch 135/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5225 - accuracy: 0.7502 - val_loss: 0.5333 - val_accuracy: 0.7412
# Epoch 136/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5223 - accuracy: 0.7502 - val_loss: 0.5332 - val_accuracy: 0.7412
# Epoch 137/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5221 - accuracy: 0.7506 - val_loss: 0.5331 - val_accuracy: 0.7419
# Epoch 138/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5219 - accuracy: 0.7511 - val_loss: 0.5331 - val_accuracy: 0.7412
# Epoch 139/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5218 - accuracy: 0.7511 - val_loss: 0.5330 - val_accuracy: 0.7406
# Epoch 140/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5216 - accuracy: 0.7517 - val_loss: 0.5329 - val_accuracy: 0.7406
# Epoch 141/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5214 - accuracy: 0.7523 - val_loss: 0.5329 - val_accuracy: 0.7400
# Epoch 142/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5213 - accuracy: 0.7520 - val_loss: 0.5328 - val_accuracy: 0.7412
# Epoch 143/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5211 - accuracy: 0.7522 - val_loss: 0.5328 - val_accuracy: 0.7412
# Epoch 144/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5210 - accuracy: 0.7525 - val_loss: 0.5327 - val_accuracy: 0.7412
# Epoch 145/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5208 - accuracy: 0.7523 - val_loss: 0.5326 - val_accuracy: 0.7425
# Epoch 146/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5206 - accuracy: 0.7528 - val_loss: 0.5326 - val_accuracy: 0.7425
# Epoch 147/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5205 - accuracy: 0.7525 - val_loss: 0.5325 - val_accuracy: 0.7425
# Epoch 148/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5203 - accuracy: 0.7525 - val_loss: 0.5325 - val_accuracy: 0.7425
# Epoch 149/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5202 - accuracy: 0.7525 - val_loss: 0.5324 - val_accuracy: 0.7437
# Epoch 150/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5200 - accuracy: 0.7527 - val_loss: 0.5324 - val_accuracy: 0.7437
# Epoch 151/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5199 - accuracy: 0.7531 - val_loss: 0.5323 - val_accuracy: 0.7425
# Epoch 152/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5197 - accuracy: 0.7525 - val_loss: 0.5323 - val_accuracy: 0.7425
# Epoch 153/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5196 - accuracy: 0.7527 - val_loss: 0.5322 - val_accuracy: 0.7425
# Epoch 154/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5195 - accuracy: 0.7528 - val_loss: 0.5322 - val_accuracy: 0.7425
# Epoch 155/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5193 - accuracy: 0.7531 - val_loss: 0.5321 - val_accuracy: 0.7425
# Epoch 156/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5192 - accuracy: 0.7525 - val_loss: 0.5321 - val_accuracy: 0.7425
# Epoch 157/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5190 - accuracy: 0.7530 - val_loss: 0.5320 - val_accuracy: 0.7431
# Epoch 158/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5189 - accuracy: 0.7531 - val_loss: 0.5320 - val_accuracy: 0.7431
# Epoch 159/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5188 - accuracy: 0.7530 - val_loss: 0.5319 - val_accuracy: 0.7431
# Epoch 160/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5186 - accuracy: 0.7536 - val_loss: 0.5319 - val_accuracy: 0.7437
# Epoch 161/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5185 - accuracy: 0.7538 - val_loss: 0.5318 - val_accuracy: 0.7437
# Epoch 162/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5184 - accuracy: 0.7539 - val_loss: 0.5318 - val_accuracy: 0.7437
# Epoch 163/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5183 - accuracy: 0.7538 - val_loss: 0.5318 - val_accuracy: 0.7437
# Epoch 164/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5181 - accuracy: 0.7541 - val_loss: 0.5317 - val_accuracy: 0.7437
# Epoch 165/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5180 - accuracy: 0.7539 - val_loss: 0.5317 - val_accuracy: 0.7450
# Epoch 166/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5179 - accuracy: 0.7542 - val_loss: 0.5316 - val_accuracy: 0.7444
# Epoch 167/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5178 - accuracy: 0.7545 - val_loss: 0.5316 - val_accuracy: 0.7437
# Epoch 168/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5176 - accuracy: 0.7538 - val_loss: 0.5316 - val_accuracy: 0.7437
# Epoch 169/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5175 - accuracy: 0.7538 - val_loss: 0.5315 - val_accuracy: 0.7437
# Epoch 170/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5174 - accuracy: 0.7542 - val_loss: 0.5315 - val_accuracy: 0.7437
# Epoch 171/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5173 - accuracy: 0.7544 - val_loss: 0.5315 - val_accuracy: 0.7444
# Epoch 172/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5172 - accuracy: 0.7541 - val_loss: 0.5314 - val_accuracy: 0.7437
# Epoch 173/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5170 - accuracy: 0.7538 - val_loss: 0.5314 - val_accuracy: 0.7437
# Epoch 174/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5169 - accuracy: 0.7542 - val_loss: 0.5314 - val_accuracy: 0.7444
# Epoch 175/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5168 - accuracy: 0.7534 - val_loss: 0.5313 - val_accuracy: 0.7444
# Epoch 176/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5167 - accuracy: 0.7539 - val_loss: 0.5313 - val_accuracy: 0.7444
# Epoch 177/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5166 - accuracy: 0.7534 - val_loss: 0.5313 - val_accuracy: 0.7444
# Epoch 178/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5165 - accuracy: 0.7536 - val_loss: 0.5312 - val_accuracy: 0.7444
# Epoch 179/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5164 - accuracy: 0.7534 - val_loss: 0.5312 - val_accuracy: 0.7437
# Epoch 180/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5163 - accuracy: 0.7536 - val_loss: 0.5312 - val_accuracy: 0.7425
# Epoch 181/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5162 - accuracy: 0.7536 - val_loss: 0.5312 - val_accuracy: 0.7419
# Epoch 182/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5161 - accuracy: 0.7534 - val_loss: 0.5311 - val_accuracy: 0.7419
# Epoch 183/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5159 - accuracy: 0.7539 - val_loss: 0.5311 - val_accuracy: 0.7419
# Epoch 184/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5158 - accuracy: 0.7534 - val_loss: 0.5311 - val_accuracy: 0.7419
# Epoch 185/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5157 - accuracy: 0.7536 - val_loss: 0.5311 - val_accuracy: 0.7419
# Epoch 186/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5156 - accuracy: 0.7539 - val_loss: 0.5310 - val_accuracy: 0.7425
# Epoch 187/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5155 - accuracy: 0.7538 - val_loss: 0.5310 - val_accuracy: 0.7425
# Epoch 188/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5154 - accuracy: 0.7539 - val_loss: 0.5310 - val_accuracy: 0.7425
# Epoch 189/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5153 - accuracy: 0.7538 - val_loss: 0.5309 - val_accuracy: 0.7425
# Epoch 190/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5152 - accuracy: 0.7531 - val_loss: 0.5309 - val_accuracy: 0.7425
# Epoch 191/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5151 - accuracy: 0.7531 - val_loss: 0.5309 - val_accuracy: 0.7425
# Epoch 192/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5150 - accuracy: 0.7534 - val_loss: 0.5309 - val_accuracy: 0.7425
# Epoch 193/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5149 - accuracy: 0.7533 - val_loss: 0.5309 - val_accuracy: 0.7425
# Epoch 194/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5148 - accuracy: 0.7536 - val_loss: 0.5308 - val_accuracy: 0.7425
# Epoch 195/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5147 - accuracy: 0.7536 - val_loss: 0.5308 - val_accuracy: 0.7425
# Epoch 196/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5146 - accuracy: 0.7538 - val_loss: 0.5308 - val_accuracy: 0.7425
# Epoch 197/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5146 - accuracy: 0.7533 - val_loss: 0.5308 - val_accuracy: 0.7425
# Epoch 198/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5145 - accuracy: 0.7536 - val_loss: 0.5307 - val_accuracy: 0.7425
# Epoch 199/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5144 - accuracy: 0.7536 - val_loss: 0.5307 - val_accuracy: 0.7425
# Epoch 200/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5143 - accuracy: 0.7534 - val_loss: 0.5307 - val_accuracy: 0.7425
# Epoch 201/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5142 - accuracy: 0.7531 - val_loss: 0.5307 - val_accuracy: 0.7425
# Epoch 202/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5141 - accuracy: 0.7536 - val_loss: 0.5307 - val_accuracy: 0.7425
# Epoch 203/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5140 - accuracy: 0.7536 - val_loss: 0.5306 - val_accuracy: 0.7425
# Epoch 204/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5139 - accuracy: 0.7547 - val_loss: 0.5306 - val_accuracy: 0.7425
# Epoch 205/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5138 - accuracy: 0.7542 - val_loss: 0.5306 - val_accuracy: 0.7419
# Epoch 206/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5137 - accuracy: 0.7539 - val_loss: 0.5306 - val_accuracy: 0.7419
# Epoch 207/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5136 - accuracy: 0.7542 - val_loss: 0.5306 - val_accuracy: 0.7406
# Epoch 208/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5136 - accuracy: 0.7541 - val_loss: 0.5306 - val_accuracy: 0.7406
# Epoch 209/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5135 - accuracy: 0.7541 - val_loss: 0.5305 - val_accuracy: 0.7406
# Epoch 210/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5134 - accuracy: 0.7539 - val_loss: 0.5305 - val_accuracy: 0.7412
# Epoch 211/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5133 - accuracy: 0.7539 - val_loss: 0.5305 - val_accuracy: 0.7412
# Epoch 212/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5132 - accuracy: 0.7536 - val_loss: 0.5305 - val_accuracy: 0.7412
# Epoch 213/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5131 - accuracy: 0.7538 - val_loss: 0.5305 - val_accuracy: 0.7412
# Epoch 214/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5131 - accuracy: 0.7539 - val_loss: 0.5305 - val_accuracy: 0.7419
# Epoch 215/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5130 - accuracy: 0.7539 - val_loss: 0.5304 - val_accuracy: 0.7419
# Epoch 216/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5129 - accuracy: 0.7536 - val_loss: 0.5304 - val_accuracy: 0.7419
# Epoch 217/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5128 - accuracy: 0.7538 - val_loss: 0.5304 - val_accuracy: 0.7419
# Epoch 218/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5127 - accuracy: 0.7541 - val_loss: 0.5304 - val_accuracy: 0.7419
# Epoch 219/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5126 - accuracy: 0.7542 - val_loss: 0.5304 - val_accuracy: 0.7419
# Epoch 220/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5126 - accuracy: 0.7539 - val_loss: 0.5304 - val_accuracy: 0.7419
# Epoch 221/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5125 - accuracy: 0.7539 - val_loss: 0.5304 - val_accuracy: 0.7419
# Epoch 222/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5124 - accuracy: 0.7542 - val_loss: 0.5303 - val_accuracy: 0.7419
# Epoch 223/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5123 - accuracy: 0.7541 - val_loss: 0.5303 - val_accuracy: 0.7419
# Epoch 224/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5122 - accuracy: 0.7544 - val_loss: 0.5303 - val_accuracy: 0.7419
# Epoch 225/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5122 - accuracy: 0.7541 - val_loss: 0.5303 - val_accuracy: 0.7412
# Epoch 226/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5121 - accuracy: 0.7545 - val_loss: 0.5303 - val_accuracy: 0.7406
# Epoch 227/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5120 - accuracy: 0.7547 - val_loss: 0.5303 - val_accuracy: 0.7406
# Epoch 228/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5119 - accuracy: 0.7544 - val_loss: 0.5303 - val_accuracy: 0.7406
# Epoch 229/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5119 - accuracy: 0.7542 - val_loss: 0.5302 - val_accuracy: 0.7406
# Epoch 230/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5118 - accuracy: 0.7545 - val_loss: 0.5302 - val_accuracy: 0.7406
# Epoch 231/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5117 - accuracy: 0.7545 - val_loss: 0.5302 - val_accuracy: 0.7406
# Epoch 232/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5116 - accuracy: 0.7544 - val_loss: 0.5302 - val_accuracy: 0.7406
# Epoch 233/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5116 - accuracy: 0.7548 - val_loss: 0.5302 - val_accuracy: 0.7412
# Epoch 234/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5115 - accuracy: 0.7548 - val_loss: 0.5302 - val_accuracy: 0.7419
# Epoch 235/500
# 100/100 [==============================] - 0s 5ms/step - loss: 0.5114 - accuracy: 0.7545 - val_loss: 0.5302 - val_accuracy: 0.7419
# Epoch 236/500
# 100/100 [==============================] - 1s 6ms/step - loss: 0.5113 - accuracy: 0.7547 - val_loss: 0.5302 - val_accuracy: 0.7419
# Epoch 237/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5113 - accuracy: 0.7552 - val_loss: 0.5302 - val_accuracy: 0.7419
# Epoch 238/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5112 - accuracy: 0.7552 - val_loss: 0.5301 - val_accuracy: 0.7419
# Epoch 239/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5111 - accuracy: 0.7550 - val_loss: 0.5301 - val_accuracy: 0.7425
# Epoch 240/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5111 - accuracy: 0.7552 - val_loss: 0.5301 - val_accuracy: 0.7425
# Epoch 241/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5110 - accuracy: 0.7550 - val_loss: 0.5301 - val_accuracy: 0.7431
# Epoch 242/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5109 - accuracy: 0.7550 - val_loss: 0.5301 - val_accuracy: 0.7431
# Epoch 243/500
# 100/100 [==============================] - 0s 5ms/step - loss: 0.5109 - accuracy: 0.7550 - val_loss: 0.5301 - val_accuracy: 0.7431
# Epoch 244/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5108 - accuracy: 0.7550 - val_loss: 0.5301 - val_accuracy: 0.7425
# Epoch 245/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5107 - accuracy: 0.7556 - val_loss: 0.5301 - val_accuracy: 0.7425
# Epoch 246/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5106 - accuracy: 0.7552 - val_loss: 0.5301 - val_accuracy: 0.7425
# Epoch 247/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5106 - accuracy: 0.7555 - val_loss: 0.5301 - val_accuracy: 0.7425
# Epoch 248/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5105 - accuracy: 0.7559 - val_loss: 0.5300 - val_accuracy: 0.7425
# Epoch 249/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5104 - accuracy: 0.7558 - val_loss: 0.5300 - val_accuracy: 0.7431
# Epoch 250/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5104 - accuracy: 0.7563 - val_loss: 0.5300 - val_accuracy: 0.7431
# Epoch 251/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5103 - accuracy: 0.7566 - val_loss: 0.5300 - val_accuracy: 0.7437
# Epoch 252/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5102 - accuracy: 0.7570 - val_loss: 0.5300 - val_accuracy: 0.7437
# Epoch 253/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5102 - accuracy: 0.7570 - val_loss: 0.5300 - val_accuracy: 0.7437
# Epoch 254/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5101 - accuracy: 0.7573 - val_loss: 0.5300 - val_accuracy: 0.7437
# Epoch 255/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5100 - accuracy: 0.7573 - val_loss: 0.5300 - val_accuracy: 0.7437
# Epoch 256/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5100 - accuracy: 0.7578 - val_loss: 0.5300 - val_accuracy: 0.7437
# Epoch 257/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5099 - accuracy: 0.7577 - val_loss: 0.5300 - val_accuracy: 0.7431
# Epoch 258/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5098 - accuracy: 0.7573 - val_loss: 0.5300 - val_accuracy: 0.7431
# Epoch 259/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5098 - accuracy: 0.7577 - val_loss: 0.5300 - val_accuracy: 0.7431
# Epoch 260/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5097 - accuracy: 0.7575 - val_loss: 0.5300 - val_accuracy: 0.7431
# Epoch 261/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5097 - accuracy: 0.7580 - val_loss: 0.5299 - val_accuracy: 0.7431
# Epoch 262/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5096 - accuracy: 0.7577 - val_loss: 0.5299 - val_accuracy: 0.7431
# Epoch 263/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5095 - accuracy: 0.7577 - val_loss: 0.5299 - val_accuracy: 0.7431
# Epoch 264/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5095 - accuracy: 0.7573 - val_loss: 0.5299 - val_accuracy: 0.7431
# Epoch 265/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5094 - accuracy: 0.7573 - val_loss: 0.5299 - val_accuracy: 0.7437
# Epoch 266/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5094 - accuracy: 0.7573 - val_loss: 0.5299 - val_accuracy: 0.7437
# Epoch 267/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5093 - accuracy: 0.7577 - val_loss: 0.5299 - val_accuracy: 0.7437
# Epoch 268/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5092 - accuracy: 0.7577 - val_loss: 0.5299 - val_accuracy: 0.7437
# Epoch 269/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5092 - accuracy: 0.7578 - val_loss: 0.5299 - val_accuracy: 0.7437
# Epoch 270/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5091 - accuracy: 0.7580 - val_loss: 0.5299 - val_accuracy: 0.7437
# Epoch 271/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5090 - accuracy: 0.7577 - val_loss: 0.5299 - val_accuracy: 0.7437
# Epoch 272/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5090 - accuracy: 0.7580 - val_loss: 0.5299 - val_accuracy: 0.7437
# Epoch 273/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5089 - accuracy: 0.7581 - val_loss: 0.5299 - val_accuracy: 0.7444
# Epoch 274/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5089 - accuracy: 0.7583 - val_loss: 0.5299 - val_accuracy: 0.7444
# Epoch 275/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5088 - accuracy: 0.7580 - val_loss: 0.5299 - val_accuracy: 0.7444
# Epoch 276/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5088 - accuracy: 0.7581 - val_loss: 0.5299 - val_accuracy: 0.7444
# Epoch 277/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5087 - accuracy: 0.7583 - val_loss: 0.5299 - val_accuracy: 0.7437
# Epoch 278/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5086 - accuracy: 0.7584 - val_loss: 0.5298 - val_accuracy: 0.7444
# Epoch 279/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5086 - accuracy: 0.7581 - val_loss: 0.5298 - val_accuracy: 0.7444
# Epoch 280/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5085 - accuracy: 0.7588 - val_loss: 0.5298 - val_accuracy: 0.7444
# Epoch 281/500
# 100/100 [==============================] - 0s 5ms/step - loss: 0.5085 - accuracy: 0.7588 - val_loss: 0.5298 - val_accuracy: 0.7444
# Epoch 282/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5084 - accuracy: 0.7589 - val_loss: 0.5298 - val_accuracy: 0.7444
# Epoch 283/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5083 - accuracy: 0.7589 - val_loss: 0.5298 - val_accuracy: 0.7444
# Epoch 284/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5083 - accuracy: 0.7591 - val_loss: 0.5298 - val_accuracy: 0.7444
# Epoch 285/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5082 - accuracy: 0.7589 - val_loss: 0.5298 - val_accuracy: 0.7444
# Epoch 286/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5082 - accuracy: 0.7591 - val_loss: 0.5298 - val_accuracy: 0.7444
# Epoch 287/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5081 - accuracy: 0.7591 - val_loss: 0.5298 - val_accuracy: 0.7444
# Epoch 288/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5081 - accuracy: 0.7592 - val_loss: 0.5298 - val_accuracy: 0.7444
# Epoch 289/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5080 - accuracy: 0.7594 - val_loss: 0.5298 - val_accuracy: 0.7444
# Epoch 290/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5080 - accuracy: 0.7594 - val_loss: 0.5298 - val_accuracy: 0.7450
# Epoch 291/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5079 - accuracy: 0.7594 - val_loss: 0.5298 - val_accuracy: 0.7450
# Epoch 292/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5078 - accuracy: 0.7595 - val_loss: 0.5298 - val_accuracy: 0.7450
# Epoch 293/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5078 - accuracy: 0.7595 - val_loss: 0.5298 - val_accuracy: 0.7450
# Epoch 294/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5077 - accuracy: 0.7597 - val_loss: 0.5298 - val_accuracy: 0.7450
# Epoch 295/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5077 - accuracy: 0.7597 - val_loss: 0.5298 - val_accuracy: 0.7444
# Epoch 296/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5076 - accuracy: 0.7600 - val_loss: 0.5298 - val_accuracy: 0.7450
# Epoch 297/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5076 - accuracy: 0.7598 - val_loss: 0.5298 - val_accuracy: 0.7450
# Epoch 298/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5075 - accuracy: 0.7600 - val_loss: 0.5298 - val_accuracy: 0.7450
# Epoch 299/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5075 - accuracy: 0.7600 - val_loss: 0.5298 - val_accuracy: 0.7450
# Epoch 300/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5074 - accuracy: 0.7598 - val_loss: 0.5298 - val_accuracy: 0.7450
# Epoch 301/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5074 - accuracy: 0.7600 - val_loss: 0.5298 - val_accuracy: 0.7450
# Epoch 302/500
# 100/100 [==============================] - 0s 5ms/step - loss: 0.5073 - accuracy: 0.7602 - val_loss: 0.5298 - val_accuracy: 0.7450
# Epoch 303/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5073 - accuracy: 0.7605 - val_loss: 0.5298 - val_accuracy: 0.7450
# Epoch 304/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5072 - accuracy: 0.7605 - val_loss: 0.5298 - val_accuracy: 0.7450
# Epoch 305/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5072 - accuracy: 0.7606 - val_loss: 0.5298 - val_accuracy: 0.7450
# Epoch 306/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5071 - accuracy: 0.7603 - val_loss: 0.5298 - val_accuracy: 0.7450
# Epoch 307/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5071 - accuracy: 0.7605 - val_loss: 0.5297 - val_accuracy: 0.7450
# Epoch 308/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5070 - accuracy: 0.7603 - val_loss: 0.5297 - val_accuracy: 0.7450
# Epoch 309/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5070 - accuracy: 0.7603 - val_loss: 0.5297 - val_accuracy: 0.7450
# Epoch 310/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5069 - accuracy: 0.7603 - val_loss: 0.5297 - val_accuracy: 0.7450
# Epoch 311/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5069 - accuracy: 0.7603 - val_loss: 0.5297 - val_accuracy: 0.7450
# Epoch 312/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5068 - accuracy: 0.7602 - val_loss: 0.5297 - val_accuracy: 0.7450
# Epoch 313/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5068 - accuracy: 0.7602 - val_loss: 0.5297 - val_accuracy: 0.7450
# Epoch 314/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5067 - accuracy: 0.7602 - val_loss: 0.5297 - val_accuracy: 0.7450
# Epoch 315/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5067 - accuracy: 0.7603 - val_loss: 0.5297 - val_accuracy: 0.7450
# Epoch 316/500
# 100/100 [==============================] - 0s 5ms/step - loss: 0.5066 - accuracy: 0.7606 - val_loss: 0.5297 - val_accuracy: 0.7437
# Epoch 317/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5066 - accuracy: 0.7606 - val_loss: 0.5297 - val_accuracy: 0.7437
# Epoch 318/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5065 - accuracy: 0.7606 - val_loss: 0.5297 - val_accuracy: 0.7437
# Epoch 319/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5065 - accuracy: 0.7608 - val_loss: 0.5297 - val_accuracy: 0.7437
# Epoch 320/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5064 - accuracy: 0.7608 - val_loss: 0.5297 - val_accuracy: 0.7437
# Epoch 321/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5064 - accuracy: 0.7608 - val_loss: 0.5297 - val_accuracy: 0.7437
# Epoch 322/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5063 - accuracy: 0.7608 - val_loss: 0.5297 - val_accuracy: 0.7437
# Epoch 323/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5063 - accuracy: 0.7608 - val_loss: 0.5297 - val_accuracy: 0.7444
# Epoch 324/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5062 - accuracy: 0.7606 - val_loss: 0.5297 - val_accuracy: 0.7437
# Epoch 325/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5062 - accuracy: 0.7608 - val_loss: 0.5297 - val_accuracy: 0.7437
# Epoch 326/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5061 - accuracy: 0.7606 - val_loss: 0.5297 - val_accuracy: 0.7437
# Epoch 327/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5061 - accuracy: 0.7608 - val_loss: 0.5297 - val_accuracy: 0.7437
# Epoch 328/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5060 - accuracy: 0.7608 - val_loss: 0.5297 - val_accuracy: 0.7444
# Epoch 329/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5060 - accuracy: 0.7606 - val_loss: 0.5297 - val_accuracy: 0.7444
# Epoch 330/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5059 - accuracy: 0.7609 - val_loss: 0.5297 - val_accuracy: 0.7444
# Epoch 331/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5059 - accuracy: 0.7608 - val_loss: 0.5297 - val_accuracy: 0.7444
# Epoch 332/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5058 - accuracy: 0.7608 - val_loss: 0.5297 - val_accuracy: 0.7444
# Epoch 333/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5058 - accuracy: 0.7609 - val_loss: 0.5297 - val_accuracy: 0.7437
# Epoch 334/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5057 - accuracy: 0.7608 - val_loss: 0.5297 - val_accuracy: 0.7437
# Epoch 335/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5057 - accuracy: 0.7611 - val_loss: 0.5297 - val_accuracy: 0.7437
# Epoch 336/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5057 - accuracy: 0.7608 - val_loss: 0.5297 - val_accuracy: 0.7444
# Epoch 337/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5056 - accuracy: 0.7609 - val_loss: 0.5297 - val_accuracy: 0.7450
# Epoch 338/500
# 100/100 [==============================] - 0s 5ms/step - loss: 0.5056 - accuracy: 0.7611 - val_loss: 0.5297 - val_accuracy: 0.7450
# Epoch 339/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5055 - accuracy: 0.7608 - val_loss: 0.5297 - val_accuracy: 0.7450
# Epoch 340/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5055 - accuracy: 0.7605 - val_loss: 0.5297 - val_accuracy: 0.7450
# Epoch 341/500
# 100/100 [==============================] - 0s 5ms/step - loss: 0.5054 - accuracy: 0.7605 - val_loss: 0.5297 - val_accuracy: 0.7450
# Epoch 342/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5054 - accuracy: 0.7609 - val_loss: 0.5297 - val_accuracy: 0.7450
# Epoch 343/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5053 - accuracy: 0.7609 - val_loss: 0.5297 - val_accuracy: 0.7450
# Epoch 344/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5053 - accuracy: 0.7611 - val_loss: 0.5297 - val_accuracy: 0.7450
# Epoch 345/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5053 - accuracy: 0.7609 - val_loss: 0.5297 - val_accuracy: 0.7444
# Epoch 346/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5052 - accuracy: 0.7609 - val_loss: 0.5297 - val_accuracy: 0.7444
# Epoch 347/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5052 - accuracy: 0.7609 - val_loss: 0.5297 - val_accuracy: 0.7444
# Epoch 348/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5051 - accuracy: 0.7613 - val_loss: 0.5297 - val_accuracy: 0.7444
# Epoch 349/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5051 - accuracy: 0.7611 - val_loss: 0.5297 - val_accuracy: 0.7437
# Epoch 350/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5050 - accuracy: 0.7614 - val_loss: 0.5297 - val_accuracy: 0.7437
# Epoch 351/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5050 - accuracy: 0.7616 - val_loss: 0.5297 - val_accuracy: 0.7431
# Epoch 352/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5049 - accuracy: 0.7614 - val_loss: 0.5297 - val_accuracy: 0.7431
# Epoch 353/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5049 - accuracy: 0.7613 - val_loss: 0.5297 - val_accuracy: 0.7425
# Epoch 354/500
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5049 - accuracy: 0.7617 - val_loss: 0.5297 - val_accuracy: 0.7425

# %%
# plot train and val acc as  a function of epochs
# your code here
fig, ax = plt.subplots(1,2,figsize = (16,4))
ax[0].plot(history.history['loss'],color='#EFAEA4',label = 'Training Loss')
ax[0].plot(history.history['val_loss'],color='#B2D7D0',label = 'Validation Loss')
ax[1].plot(history.history['accuracy'],color='#EFAEA4',label = 'Training Accuracy')
ax[1].plot(history.history['val_accuracy'],color='#B2D7D0',label = 'Validation Accuracy')
ax[0].legend()
ax[1].legend()
ax[0].set_xlabel('Epochs')
ax[1].set_xlabel('Epochs');
ax[0].set_ylabel('Loss')
ax[1].set_ylabel('Accuracy %');
fig.suptitle('Model Training', fontsize = 24)
# Out:
# Text(0.5, 0.98, 'Model Training')

# %%
# primer to print: 
# print("NN_model_train_auc:", roc_auc_score(y_train, y_hat))
# your code here 
y_hat=model.predict(X_train)
print("NN_model_train_auc:", roc_auc_score(y_train,y_hat ))
# Out:
# NN_model_train_auc: 0.8262840474028261

# %%
# your code here
y_hat_test=model.predict(X_test)
print("NN_model_train_auc:", roc_auc_score(y_test,y_hat_test ))
# Out:
# NN_model_train_auc: 0.8078402575535812

# %% [markdown]
# <div class='exercise-r'>
#
# **1.3**
#
# </div>

# %%
# Fit the logistic regression model
# your code here

# %% [markdown]
# <div class='exercise-r'>
#
# **1.4**
#
# **1.4.1**
#
# </div>

# %%
# your code here

# %% [markdown]
# **INTERPRETATION:**

# %% [markdown]
# *Your answer here*

# %% [markdown]
# <div class='exercise-r'>
#
# **1.4.2**
# </div>

# %%
# your code here

# %% [markdown]
# <div class='exercise-r'>
#
# **1.4.3**
#
# </div>

# %%
# your code here

# %% [markdown]
# <div class='exercise-r'>
#
# **1.4.4**
#
# </div>

# %%
# your code here

# %% [markdown]
# **INTERPRETATION:**

# %% [markdown]
# *your answer here*

# %% [markdown]
# <div class='exercise-r'>
#
# **1.5**
#
# </div>

# %%
def progressbar(n_step, n_total):
    """Prints self-updating progress bar to stdout to track for-loop progress
    
    There are entire 3rd-party libraries dedicated to custom progress-bars.
    A simple function like this is often more than enough to get the job done.
    
    :param n_total: total number of expected for-loop iterations
    :type n_total: int
    :param n_step: current iteration number, starting at 0
    :type n_step: int

    .. example::
    
        for i in range(n_iterations):
            progressbar(i, n_iterations)
            
    .. source:
    
        This function is a simplified version of code found here:
        https://stackoverflow.com/questions/3160699/python-progress-bar/15860757#15860757
    """
    n_step = n_step + 1
    barlen = 50
    progress = n_step / n_total
    block = int(round(barlen * progress))
    status = ""
    if n_step == n_total:
        status = "Done...\r\n\n"
    text = "\r [{0}] {1}/{2} {3}".format(
        "=" * block + "-" * (barlen - block),
        n_step,
        n_total,
        status,
    )
    sys.stdout.write(text)
    sys.stdout.flush()

# %%
# %%time
# Bootstrap and train your networks and get predictions on fixed X test
# your code here
# Out:
# Wall time: 0 ns

# %%
# generate your plot
# your code here

# %% [markdown]
# **INTERPRETATION:**

# %% [markdown]
# *your answer here*

# %% [markdown]
# <div class='exercise-r'>
#
# **1.6**
#
# </div>

# %%
# your code here

# %% [markdown]
# **INTERPRETATION:**

# %% [markdown]
# *your answer here*

# %% [markdown]
# <div class="alert alert-block alert-danger" style="color:black;background-color:#E7F4FA">
#
#
# <h1>PART 2 [50 pts]: Kannada MNIST</h1>
# <br /><br />
# [Return to contents](#contents)
# <br /><br />
#
# <a id="part2intro"></a>
# <h2> Problem Statement </h2>
# <br /><br />
# [Return to contents](#contents)
# <br /><br />
#
# ANNs can be prone to overfitting, where they learn specific patterns present in the training data, but the patterns do not generalize to new data.
# <br /><br />
# There are several methods used to improve ANN generalization.
# <br /><br />
# One approach is to use an architecture just barely wide or deep enough to fit the data. The idea here is that smaller networks are less expressive and thus less able to overfit the data.
# <br /><br />
# However, it is difficult to know a priori the correct size of the ANN, and it is computationally costly to hunt for the correct size. Given this, other methodologies are used to prevent overfitting and improve ANNs' generalizability. These methodologies, like other techniques that combat overfitting, fall under the umbrella term of "regularization".
# <br /><br />
# In this problem, you are asked to regularize a network of a given architecture.
#
# <a id="part2about"></a>
# <br /><br />
# <h3> The Kannada MNIST Dataset </h3>
# <br /><br />
# [Return to contents](#contents)
# <br /><br />
#
# ![](https://www.googleapis.com/download/storage/v1/b/kaggle-user-content/o/inbox%2F3630446%2F1e01bcc28b5ccb7ad38a4ffefb13cde0%2Fwondu.png?generation=1603204077179447&alt=media)
#
# <br /><br />
# For this problem, we will be working with a modified version of [Kannada MNIST dataset](https://arxiv.org/pdf/1908.01242.pdf) , which is a large database of handwritten digits in the indigenous language *Kannada*.
# <br /><br />
# This dataset consists of 60,000 28x28 grayscale images of the ten digits, along with a test set of 10,000 images.
# <br /><br />
# For this homework, we will simplify the problem by only use the digits labeled `0` and `1` owing to the similarity of the two symbols, and we want to use a total of 1200 samples for training (this includes the data you will use for validation).
# <br /><br />
# To understand the dataset better, we recommend this [article](https://towardsdatascience.com/a-new-handwritten-digits-dataset-in-ml-town-kannada-mnist-69df0f2d1456) by Vinay Prabhu, the curator of the dataset.
# <br /><br />
# <a id="part2data"></a>
#
# <h4> Downloading the Data Files </h4>
# <br />
# [Return to contents](#contents)
# <br />
# Please download all files from resources on Ed.
# <br /><br />
# Here's a brief description of the available files:
# <br /><br />
# - `kmnist_train.csv` is our training dataset and the last column contains our response class. The 784 other columns correspond to the pixel values of the 28x28 dimension image.
# <br /><br />
# Class 0 means a sample is the handwritten digit `0` and class 1 means a sample is the handwritten digit `1` in the Kannada language.
# <br />
# - `kmnist_test.csv` has a structure similar to `kmnist_train.csv` but you will use this only for testing.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger" style="color:black;background-color:#E7F4FA">
#
# <h2>PART2 Questions</h2>
# <br /><br />
# [Return to contents](#contents)
#
# <br /><br />
# **2.1 [5 points]** **Get the data:**
#
# - Download data from Ed resources.
# - We will utilize `kmnist_test.csv` in question 2.3.4 only.
# - Load the data and use the matplotlib function `imshow` to display a handwritten 0 and a handwritten 1.
# <br /><br />
#
# **2.2 [15 points]** **Overfit an ANN:**
#
# Build a fully-connected network (FCN) with the architecture given below using `tensorflow.keras` and assign it to a variable called `model_overfit`:
#
# - Number of hidden layers: 3
# - Nodes per hidden layer: 100, 100, 100
# - Activation function: ReLU
# - Loss function: binary_crossentropy
# - Output unit: Sigmoid
# - Optimizer: adam (use the defaults; no other tuning)
# - Epochs: no more than 2,000
# - Batch size: 128
# - Validation size: 0.3
#
# ![](https://www.googleapis.com/download/storage/v1/b/kaggle-user-content/o/inbox%2F3630446%2F6a491ff8d4ff590dc8ded9a25461cd4b%2FScreenshot%202020-10-20%20at%209.42.36%20PM.png?generation=1603210420701577&alt=media)
#
# This ANN, when trained on the dataset, will overfit to the training set. Plot the training accuracy and validation accuracy (the x-axis should represent the number of epochs, and the y-axis should represent the accuracy). Explain how you can tell the model is overfitting.
#
# <a id="part2_3"></a>
# <br /><br />
#
# **2.3 [30 points]** **Regularize overfit network:**
#
# Create an ANN that doesn't overfit and report your accuracy on the test set.
# <br /><br />
# **DON'TS**
#
# **Don't change the architecture**. In other words, keep the number of layers, number of nodes, activation function,  loss function and output unit the same. **No CNNs/RNNs/enhancements.**
#
# <br />
#
# **NOTE**: We strongly discourage you to use a different training set than the one provided to you but data augmentation is allowed.
#
# <br /><br />
#
# **DOS**
#
# You can change the number of epochs (max 2000), batch size, optimizer, and of course, add elements that can help to regularize (e.g., dropout, L2 norm, etc.). You can also do data augmentation.
# <br /><br />
#
# - **2.3.1** Display your model summary and your training and validation accuracy and loss.
#
# <br />
#
# - **2.3.2** Print the difference between the training and validation accuracies and the difference between the training and validation losses for the final trained epoch used by your model.
#
# <br />
#
# - **2.3.3** Plot the training accuracy and validation accuracy as a function of epochs.
# <br />
#
# - **2.3.4** Once your model is trained, evaluate your model on the test dataset and provide the test accuracy.
#
#
# <br /><br />
#
# </div>

# %% [markdown]
# <a id="part2solutions"></a>
#
# ## PART 2 Solutions
#
# [Return to contents](#contents)

# %% [markdown]
# <div class='exercise-r'>
#
# **2.1**
#
# </div>

# %%
# your code here

# %% [markdown]
# <div class='exercise-r'>
#
# **2.2**
#
# </div>

# %%
# your code here

# %% [markdown]
# **INTERPRETATION:**

# %% [markdown]
# *your answer here*

# %% [markdown]
# <div class='exercise-r'>
#
# **2.3**
#
# **2.3.1**
#
# </div>

# %%
# your code here

# %% [markdown]
# <div class='exercise-r'>
#
# **2.3.2**
#
# </div>

# %%
# your code here

# %% [markdown]
# <div class='exercise-r'>
#
# **2.3.3**
#
# </div>

# %%
# your code here

# %% [markdown]
# <div class='exercise-r'>
#
# **2.3.4**
#
# </div>

# %%
# your code here
